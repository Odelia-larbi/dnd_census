# %% [markdown]
# <a href="https://colab.research.google.com/github/PUBPOL-2130/notebooks/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install matplotlib pandas us census

# %config InlineBackend.figure_formats = ["svg"]

import matplotlib.pyplot as plt
import pandas as pd

from census import Census
from us import states
# Out:
# Requirement already satisfied: matplotlib in c:\users\homsb\notebooks\.venv\lib\site-packages (3.10.3)
# Requirement already satisfied: pandas in c:\users\homsb\notebooks\.venv\lib\site-packages (2.3.0)
# Requirement already satisfied: us in c:\users\homsb\notebooks\.venv\lib\site-packages (3.2.0)
# Requirement already satisfied: census in c:\users\homsb\notebooks\.venv\lib\site-packages (0.8.24)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\homsb\notebooks\.venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\homsb\notebooks\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\homsb\notebooks\.venv\lib\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\homsb\notebooks\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\homsb\notebooks\.venv\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\homsb\notebooks\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\homsb\notebooks\.venv\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\homsb\notebooks\.venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\homsb\notebooks\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\homsb\notebooks\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\homsb\notebooks\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: jellyfish in c:\users\homsb\notebooks\.venv\lib\site-packages (from us) (1.2.0)
# Requirement already satisfied: requests>=1.1.0 in c:\users\homsb\notebooks\.venv\lib\site-packages (from census) (2.32.4)
# Requirement already satisfied: six>=1.5 in c:\users\homsb\notebooks\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\homsb\notebooks\.venv\lib\site-packages (from requests>=1.1.0->census) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\homsb\notebooks\.venv\lib\site-packages (from requests>=1.1.0->census) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\homsb\notebooks\.venv\lib\site-packages (from requests>=1.1.0->census) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\homsb\notebooks\.venv\lib\site-packages (from requests>=1.1.0->census) (2025.6.15)
# Note: you may need to restart the kernel to use updated packages.

# %%
census = Census("", year=2020)

# %% [markdown]
# # Week 2: Exploring the U.S. Census, part 1 (population data)
#
# In this notebook, we'll explore the most famous and essential dataset published by the U.S. Census Bureau: the decennial enumeration of the U.S. population. This enumeration is [required by Article I of the U.S. Constitution](https://www.census.gov/programs-surveys/decennial-census/about/census-constitution.html), and the challenges of processing Census data as the national population grew throughout the 19th century led to the development of [a tabulating machine](https://www.computerhistory.org/revolution/punched-cards/2/2) that was [first used for processing the 1890 U.S. Census](https://www.smithsonianmag.com/smithsonian-institution/herman-holleriths-tabulating-machine-2504989/). This machine read punched cards that encoded Census responses and generated summary statistics (such as the number of foreign-born children under 18 in a particular state, or the number of married women in a particular city). The company that developed this tabulating machine was later renamed to IBM.
#
# The technical demands of analyzing U.S. Census data were therefore a catalyst in the early development of computing; in the 130 years or so since the dawn of this automated tabulation technology, Census data has become exponentially more detailed and accessible. Here, we'll focus on a small slice of the 2010 and 2020 decennial Census data published online via the [Census API](https://www.census.gov/data/developers/data-sets.html).
#
#
# <img width="600" alt="Herman Hollerith's tabulating machine" src="https://www.ibm.com/content/dam/connectedassets-adobe-cms/worldwide-content/arc/cf/ul/g/a6/a6/hollerithtabulator_sorter.component.simple-narrative-nocrop-xl-retina.ts=1702922330895.jpg/content/adobe-cms/us/en/history/punched-card-tabulator/jcr:content/root/table_of_contents/body/content_section_styled/content-section-body/simple_narrative/image">
#
# _Herman Hollerith's tabulating machine for the 1890 U.S. Census (photo credit: [IBM](https://www.ibm.com/history/punched-card-tabulator))._

# %% [markdown]
# ## Fetching population data
#
# Here, we'll retrieve population statistics by race from the Census API for all counties in New York. Census data releases are organized into tables; [Table P1](https://data.census.gov/table/DECENNIALPL2020.P1?g=040XX00US36) breaks down population by racial category. For ease of use, we'll map the column names returned by the Census API to their corresponding racial categories: for instance, the `P1_004N` column corresponds to Black population. (Full column definitions are available in the [API documentation](https://api.census.gov/data/2020/dec/pl/variables.html).)

# %%
p1_population_columns = {
    "P1_003N": "white",	      # White alone
    "P1_004N": "black",	      # Black or African American alone
    "P1_005N": "amin",        # American Indian and Alaska Native alone
    "P1_006N": "asian",       # Asian alone
    "P1_007N": "nhpi",        # Native Hawaiian and Other Pacific Islander alone
    "P1_008N": "other",       # Some Other Race alone
    "P1_009N": "two_or_more", # Two or more races
}

# %% [markdown]
# When fetching data from the Census API, we usually identify geographic regions (states, counties, etc.) by their [FIPS code](https://en.wikipedia.org/wiki/Federal_Information_Processing_Standard_state_code). For instance, the FIPS code for the state of New York is 36. The `us` package exposes identifiers (FIPS codes, postal abbreviations) for the U.S. states.

# %%
state = states.NY

# %%
print(state, state.abbr, state.fips)
# Out:
# New York NY 36

# %% [markdown]
# Here, we specify:
# * The columns we want to fetch from the Census API (the `NAME` column, and the 7 columns from Table P1 listed in `p1_population_columns` above).
# * The regions we want to fetch column values for (all counties in New York).

# %%
county_populations = census.pl.get(
    ("NAME", *p1_population_columns),
    geo={
        "for": "county:*",
        "in": f"state:{state.fips}",
    }
)

# %% [markdown]
# **Note: there are several ways to modify the above code to get data for *multiple* counties and *multiple* states.**
#
# For example, if you want to get data for multiple counties you can simply list them out by their FIPS codes.
#
# ```
# county_populations = census.pl.get(
#     ("NAME", *p1_population_columns),
#     geo={
#         "for": "county:001,002,003",
#         "in": f"state:{state.fips}",
#     }
# )
# ```
#
# Or, if you want to get data for all counties in *multiple states* you can list out the states by their FIPS codes.
#
# ```
# county_populations = census.pl.get(
#     ("NAME", *p1_population_columns),
#     geo={
#         "for": "county:*",
#         "in": "state:01,02",
#     }
# )
# ```
#
# The syntax `f"state:{state.fips}"` is a kind of [string formatting](https://docs.python.org/3/tutorial/inputoutput.html) in Python, which allows you to dynamically change the content of the string based on other defined variables (in this case, `state.fips`). You can alternatively replace this code with the hard-coded FIPS values (e.g., `"state:01"`).
#
# Lastly, remember that the asterisk `*` allows you to select *all* values corresponding to either counties or states.

# %% [markdown]
# The Census API returns a list of dictionaries; each contains column values for a county.

# %%
county_populations[0]
# Out:
# {'NAME': 'Albany County, New York',
#  'P1_003N': 215496.0,
#  'P1_004N': 43206.0,
#  'P1_005N': 845.0,
#  'P1_006N': 24473.0,
#  'P1_007N': 183.0,
#  'P1_008N': 8873.0,
#  'P1_009N': 21772.0,
#  'state': '36',
#  'county': '001'}

# %% [markdown]
# We can convert this raw response to a Pandas `DataFrame` without any further manipulation.

# %%
race_df = pd.DataFrame(county_populations)

# %%
race_df.head(5)
# Out:
#                            NAME   P1_003N   P1_004N  P1_005N  P1_006N  \
# 0       Albany County, New York  215496.0   43206.0    845.0  24473.0
# 1     Allegany County, New York   42555.0     829.0     91.0    379.0
# 2        Bronx County, New York  207573.0  487118.0  21539.0  69559.0
# 3       Broome County, New York  158674.0   12684.0    556.0   9372.0
# 4  Cattaraugus County, New York   68128.0    1043.0   2706.0    567.0
#
#    P1_007N   P1_008N   P1_009N state county
# 0    183.0    8873.0   21772.0    36    001
# 1      9.0     678.0    1915.0    36    003
# 2   1640.0  493052.0  192173.0    36    005
# 3     84.0    3975.0   13338.0    36    007
# 4     14.0     571.0    4013.0    36    009

# %% [markdown]
# ## Postprocessing
#
# We can make `race_df` more usable by applying our mapping from raw column names to human-readable racial categories. We don't need the state and county FIPS codes returned by the Census API by default in the `state` and `county` columns, so we'll drop those columns.

# %%
race_df = race_df.rename(
    columns={"NAME": "name", **p1_population_columns}
).drop(
    columns=["state", "county"]
).set_index("name")

# %%
race_df.head(10)
# Out:
#                                  white     black     amin    asian    nhpi  \
# name
# Albany County, New York       215496.0   43206.0    845.0  24473.0   183.0
# Allegany County, New York      42555.0     829.0     91.0    379.0     9.0
# Bronx County, New York        207573.0  487118.0  21539.0  69559.0  1640.0
# Broome County, New York       158674.0   12684.0    556.0   9372.0    84.0
# Cattaraugus County, New York   68128.0    1043.0   2706.0    567.0    14.0
# Cayuga County, New York        67017.0    2910.0    310.0    385.0    54.0
# Chautauqua County, New York   109333.0    3354.0    673.0    818.0    57.0
# Chemung County, New York       70463.0    5315.0    240.0   1432.0    15.0
# Chenango County, New York      43531.0     357.0    126.0    245.0    15.0
# Clinton County, New York       70142.0    3060.0    285.0    975.0    26.0
#
#                                  other  two_or_more
# name
# Albany County, New York         8873.0      21772.0
# Allegany County, New York        678.0       1915.0
# Bronx County, New York        493052.0     192173.0
# Broome County, New York         3975.0      13338.0
# Cattaraugus County, New York     571.0       4013.0
# Cayuga County, New York         1033.0       4539.0
# Chautauqua County, New York     4278.0       9144.0
# Chemung County, New York         947.0       5736.0
# Chenango County, New York        353.0       2593.0
# Clinton County, New York        1010.0       4345.0

# %% [markdown]
# We can sum the values in each column to compute population totals by racial category for the state.

# %%
race_df.sum(axis=0)
# Out:
# white          11143349.0
# black           2986172.0
# amin             149690.0
# asian           1933127.0
# nhpi              10815.0
# other           2210633.0
# two_or_more     1767463.0
# dtype: float64

# %% [markdown]
# Similarly, we can sum the values in each row to compute population totals (across all racial categories) for each county.

# %%
race_df.sum(axis=1)
# Out:
# name
# Albany County, New York          314848.0
# Allegany County, New York         46456.0
# Bronx County, New York          1472654.0
# Broome County, New York          198683.0
# Cattaraugus County, New York      77042.0
#                                   ...
# Washington County, New York       61302.0
# Wayne County, New York            91283.0
# Westchester County, New York    1004457.0
# Wyoming County, New York          40531.0
# Yates County, New York            24774.0
# Length: 62, dtype: float64

# %% [markdown]
# ### Visualizing demographics with a pie chart

# %% [markdown]
# We can visualize the demographic breakdown of a particular county with [Pandas' pie chart function](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.pie.html).

# %%
race_df
# Out:
#                                  white     black     amin    asian    nhpi  \
# name
# Albany County, New York       215496.0   43206.0    845.0  24473.0   183.0
# Allegany County, New York      42555.0     829.0     91.0    379.0     9.0
# Bronx County, New York        207573.0  487118.0  21539.0  69559.0  1640.0
# Broome County, New York       158674.0   12684.0    556.0   9372.0    84.0
# Cattaraugus County, New York   68128.0    1043.0   2706.0    567.0    14.0
# ...                                ...       ...      ...      ...     ...
# Washington County, New York    55162.0    1715.0    174.0    326.0    23.0
# Wayne County, New York         80476.0    2562.0    263.0    487.0    15.0
# Westchester County, New York  533150.0  141094.0   7466.0  65707.0   339.0
# Wyoming County, New York       36046.0    1999.0     98.0    218.0     6.0
# Yates County, New York         23264.0     161.0     49.0     93.0    10.0
#
#                                  other  two_or_more
# name
# Albany County, New York         8873.0      21772.0
# Allegany County, New York        678.0       1915.0
# Bronx County, New York        493052.0     192173.0
# Broome County, New York         3975.0      13338.0
# Cattaraugus County, New York     571.0       4013.0
# ...                                ...          ...
# Washington County, New York      703.0       3199.0
# Wayne County, New York          1667.0       5813.0
# Westchester County, New York  146911.0     109790.0
# Wyoming County, New York         594.0       1570.0
# Yates County, New York           250.0        947.0
#
# [62 rows x 7 columns]

# %%
race_df.T
# Out:
# name         Albany County, New York  Allegany County, New York  \
# white                       215496.0                    42555.0
# black                        43206.0                      829.0
# amin                           845.0                       91.0
# asian                        24473.0                      379.0
# nhpi                           183.0                        9.0
# other                         8873.0                      678.0
# two_or_more                  21772.0                     1915.0
#
# name         Bronx County, New York  Broome County, New York  \
# white                      207573.0                 158674.0
# black                      487118.0                  12684.0
# amin                        21539.0                    556.0
# asian                       69559.0                   9372.0
# nhpi                         1640.0                     84.0
# other                      493052.0                   3975.0
# two_or_more                192173.0                  13338.0
#
# name         Cattaraugus County, New York  Cayuga County, New York  \
# white                             68128.0                  67017.0
# black                              1043.0                   2910.0
# amin                               2706.0                    310.0
# asian                               567.0                    385.0
# nhpi                                 14.0                     54.0
# other                               571.0                   1033.0
# two_or_more                        4013.0                   4539.0
#
# name         Chautauqua County, New York  Chemung County, New York  \
# white                           109333.0                   70463.0
# black                             3354.0                    5315.0
# amin                               673.0                     240.0
# asian                              818.0                    1432.0
# nhpi                                57.0                      15.0
# other                             4278.0                     947.0
# two_or_more                       9144.0                    5736.0
#
# name         Chenango County, New York  Clinton County, New York  ...  \
# white                          43531.0                   70142.0  ...
# black                            357.0                    3060.0  ...
# amin                             126.0                     285.0  ...
# asian                            245.0                     975.0  ...
# nhpi                              15.0                      26.0  ...
# other                            353.0                    1010.0  ...
# two_or_more                     2593.0                    4345.0  ...
#
# name         Sullivan County, New York  Tioga County, New York  \
# white                          56040.0                 44557.0
# black                           6814.0                   452.0
# amin                             418.0                    75.0
# asian                           1597.0                   379.0
# nhpi                              29.0                    18.0
# other                           6168.0                   399.0
# two_or_more                     7558.0                  2575.0
#
# name         Tompkins County, New York  Ulster County, New York  \
# white                          78657.0                 141728.0
# black                           4597.0                  11063.0
# amin                             353.0                    829.0
# asian                          10532.0                   3860.0
# nhpi                              47.0                     63.0
# other                           2855.0                   8390.0
# two_or_more                     8699.0                  15918.0
#
# name         Warren County, New York  Washington County, New York  \
# white                        59911.0                      55162.0
# black                          799.0                       1715.0
# amin                           170.0                        174.0
# asian                          753.0                        326.0
# nhpi                             1.0                         23.0
# other                          497.0                        703.0
# two_or_more                   3606.0                       3199.0
#
# name         Wayne County, New York  Westchester County, New York  \
# white                       80476.0                      533150.0
# black                        2562.0                      141094.0
# amin                          263.0                        7466.0
# asian                         487.0                       65707.0
# nhpi                           15.0                         339.0
# other                        1667.0                      146911.0
# two_or_more                  5813.0                      109790.0
#
# name         Wyoming County, New York  Yates County, New York
# white                         36046.0                 23264.0
# black                          1999.0                   161.0
# amin                             98.0                    49.0
# asian                           218.0                    93.0
# nhpi                              6.0                    10.0
# other                           594.0                   250.0
# two_or_more                    1570.0                   947.0
#
# [7 rows x 62 columns]

# %%
county = "Tompkins County, New York"
county = "white"
ax = race_df.plot.pie(y=county, figsize=(10, 10), legend=False)
ax.set_title(f"Population of {county} by race")
ax.set_ylabel("")
plt.show()

# %% [markdown]
# We can visualize the demographic breakdown of the whole state in a similar fashion: first, we compute total population by race for the entire state (as illustrated in the section above), and then we plot the resulting Pandas `Series`. This pie chart improves on the county-level pie chart above by showing percentages for each racial category (rounded to the nearest 0.1%).

# %%
ax = race_df.sum(axis=0).plot.pie(figsize=(10, 10), autopct="%1.1f%%")
ax.set_ylabel("")
ax.set_title(f"Population of {state} (state) by race")
plt.show()

# %% [markdown]
# ### Computing percentages

# %% [markdown]
# In order to answer questions like "which county in New York has the largest _share_ of Black population?", it's necessary to convert absolute population counts to percentages. To do this, it's convenient to compute a `total` column, then create percentage columns by dividing each race column by the `total` column, then scaling by 100 to convert from fractional values to percentages. Pandas' vector arithmetic functionality makes these operations relatively simple to write: rather than explicitly iterating through each row, we can simply write the multiplication and division operations in terms of columns. The operations will be applied to each row!

# %%
race_df["total"] = race_df.sum(axis=1)

# %%
race_df.head(5)
# Out:
#                                  white     black     amin    asian    nhpi  \
# name
# Albany County, New York       215496.0   43206.0    845.0  24473.0   183.0
# Allegany County, New York      42555.0     829.0     91.0    379.0     9.0
# Bronx County, New York        207573.0  487118.0  21539.0  69559.0  1640.0
# Broome County, New York       158674.0   12684.0    556.0   9372.0    84.0
# Cattaraugus County, New York   68128.0    1043.0   2706.0    567.0    14.0
#
#                                  other  two_or_more      total
# name
# Albany County, New York         8873.0      21772.0   314848.0
# Allegany County, New York        678.0       1915.0    46456.0
# Bronx County, New York        493052.0     192173.0  1472654.0
# Broome County, New York         3975.0      13338.0   198683.0
# Cattaraugus County, New York     571.0       4013.0    77042.0

# %%
categories = list(p1_population_columns.values())
categories
# Out:
# ['white', 'black', 'amin', 'asian', 'nhpi', 'other', 'two_or_more']

# %%
for col in categories:
    race_df[f"{col}_pct"] = 100 * race_df[col] / race_df["total"]

# %%
race_df
# Out:
#                                  white     black     amin    asian    nhpi  \
# name
# Albany County, New York       215496.0   43206.0    845.0  24473.0   183.0
# Allegany County, New York      42555.0     829.0     91.0    379.0     9.0
# Bronx County, New York        207573.0  487118.0  21539.0  69559.0  1640.0
# Broome County, New York       158674.0   12684.0    556.0   9372.0    84.0
# Cattaraugus County, New York   68128.0    1043.0   2706.0    567.0    14.0
# ...                                ...       ...      ...      ...     ...
# Washington County, New York    55162.0    1715.0    174.0    326.0    23.0
# Wayne County, New York         80476.0    2562.0    263.0    487.0    15.0
# Westchester County, New York  533150.0  141094.0   7466.0  65707.0   339.0
# Wyoming County, New York       36046.0    1999.0     98.0    218.0     6.0
# Yates County, New York         23264.0     161.0     49.0     93.0    10.0
#
#                                  other  two_or_more      total  white_pct  \
# name
# Albany County, New York         8873.0      21772.0   314848.0  68.444456
# Allegany County, New York        678.0       1915.0    46456.0  91.602807
# Bronx County, New York        493052.0     192173.0  1472654.0  14.095164
# Broome County, New York         3975.0      13338.0   198683.0  79.862897
# Cattaraugus County, New York     571.0       4013.0    77042.0  88.429688
# ...                                ...          ...        ...        ...
# Washington County, New York      703.0       3199.0    61302.0  89.984014
# Wayne County, New York          1667.0       5813.0    91283.0  88.160994
# Westchester County, New York  146911.0     109790.0  1004457.0  53.078429
# Wyoming County, New York         594.0       1570.0    40531.0  88.934396
# Yates County, New York           250.0        947.0    24774.0  93.904900
#
#                               black_pct  amin_pct  asian_pct  nhpi_pct  \
# name
# Albany County, New York       13.722812  0.268383   7.772957  0.058123
# Allegany County, New York      1.784484  0.195884   0.815826  0.019373
# Bronx County, New York        33.077559  1.462597   4.723377  0.111364
# Broome County, New York        6.384039  0.279843   4.717062  0.042278
# Cattaraugus County, New York   1.353807  3.512370   0.735962  0.018172
# ...                                 ...       ...        ...       ...
# Washington County, New York    2.797625  0.283841   0.531793  0.037519
# Wayne County, New York         2.806656  0.288115   0.533506  0.016432
# Westchester County, New York  14.046793  0.743287   6.541544  0.033750
# Wyoming County, New York       4.932027  0.241790   0.537860  0.014803
# Yates County, New York         0.649875  0.197788   0.375394  0.040365
#
#                               other_pct  two_or_more_pct
# name
# Albany County, New York        2.818185         6.915083
# Allegany County, New York      1.459445         4.122180
# Bronx County, New York        33.480505        13.049433
# Broome County, New York        2.000674         6.713206
# Cattaraugus County, New York   0.741154         5.208847
# ...                                 ...              ...
# Washington County, New York    1.146782         5.218427
# Wayne County, New York         1.826189         6.368108
# Westchester County, New York  14.625912        10.930284
# Wyoming County, New York       1.465545         3.873578
# Yates County, New York         1.009122         3.822556
#
# [62 rows x 15 columns]

# %% [markdown]
# Armed with these percentages, we can now answer demographic questions cast in terms of population shares. For instance, sorting `race_df` by `white_pct` shows that Bronx County contains the smallest share of white population in the state, while Lewis County contains the greatest share.

# %%
race_df.sort_values(by=["white_pct"])
# Out:
#                                   white     black     amin     asian    nhpi  \
# name
# Bronx County, New York         207573.0  487118.0  21539.0   69559.0  1640.0
# Queens County, New York        621475.0  403077.0  30513.0  660631.0  1718.0
# Kings County, New York        1028774.0  772050.0  20598.0  373680.0  1487.0
# New York County, New York      847604.0  229361.0   9969.0  221995.0  1795.0
# Westchester County, New York   533150.0  141094.0   7466.0   65707.0   339.0
# ...                                 ...       ...      ...       ...     ...
# Chenango County, New York       43531.0     357.0    126.0     245.0    15.0
# Schuyler County, New York       16750.0     101.0     50.0     108.0     1.0
# Hamilton County, New York        4785.0      31.0     14.0      12.0     1.0
# Yates County, New York          23264.0     161.0     49.0      93.0    10.0
# Lewis County, New York          25121.0     109.0     57.0      76.0    11.0
#
#                                  other  two_or_more      total  white_pct  \
# name
# Bronx County, New York        493052.0     192173.0  1472654.0  14.095164
# Queens County, New York       444686.0     243364.0  2405464.0  25.835972
# Kings County, New York        302186.0     237299.0  2736074.0  37.600372
# New York County, New York     208086.0     175441.0  1694251.0  50.028243
# Westchester County, New York  146911.0     109790.0  1004457.0  53.078429
# ...                                ...          ...        ...        ...
# Chenango County, New York        353.0       2593.0    47220.0  92.187632
# Schuyler County, New York         93.0        795.0    17898.0  93.585876
# Hamilton County, New York         22.0        242.0     5107.0  93.694929
# Yates County, New York           250.0        947.0    24774.0  93.904900
# Lewis County, New York           184.0       1024.0    26582.0  94.503800
#
#                               black_pct  amin_pct  asian_pct  nhpi_pct  \
# name
# Bronx County, New York        33.077559  1.462597   4.723377  0.111364
# Queens County, New York       16.756726  1.268487  27.463766  0.071421
# Kings County, New York        28.217439  0.752831  13.657525  0.054348
# New York County, New York     13.537605  0.588402  13.102840  0.105947
# Westchester County, New York  14.046793  0.743287   6.541544  0.033750
# ...                                 ...       ...        ...       ...
# Chenango County, New York      0.756036  0.266836   0.518848  0.031766
# Schuyler County, New York      0.564309  0.279361   0.603419  0.005587
# Hamilton County, New York      0.607010  0.274134   0.234972  0.019581
# Yates County, New York         0.649875  0.197788   0.375394  0.040365
# Lewis County, New York         0.410052  0.214431   0.285908  0.041381
#
#                               other_pct  two_or_more_pct
# name
# Bronx County, New York        33.480505        13.049433
# Queens County, New York       18.486496        10.117133
# Kings County, New York        11.044511         8.672974
# New York County, New York     12.281887        10.355077
# Westchester County, New York  14.625912        10.930284
# ...                                 ...              ...
# Chenango County, New York      0.747565         5.491317
# Schuyler County, New York      0.519611         4.441837
# Hamilton County, New York      0.430781         4.738594
# Yates County, New York         1.009122         3.822556
# Lewis County, New York         0.692198         3.852231
#
# [62 rows x 15 columns]

# %% [markdown]
# This histogram indicates that most counties in New York have a relatively small Black population share (most of the mass is below the 10% mark), but there are a few outlying counties with a large concentration of Black population.

# %%
ax = race_df["black_pct"].hist(bins=20)
ax.set_xlabel("% Black")
ax.set_ylabel("Count")
ax.set_title("Black population in New York counties")
plt.show()

# %% [markdown]
# ## Adding a dimension: Hispanic or Latino origin
#
# The U.S. Census Bureau does not consider "Hispanic or Latino" a racial category; [rather, it is an ethnic category](https://www.census.gov/acs/www/about/why-we-ask-each-question/ethnicity/) ([this may change with the 2030 Census](https://www.npr.org/2023/01/26/1151608403/mena-race-categories-us-census-middle-eastern-latino-hispanic)). Hispanic or Latino origin and racial identification were therefore considered in separate questions on the 2020 Census questionnaire (if you're curious about the precise wording of the questions, see [this PDF of the questionnaire](https://www2.census.gov/programs-surveys/decennial/2020/technical-documentation/questionnaires-and-instructions/questionnaires/2020-informational-questionnaire-english_DI-Q1.pdf)).
#
# [Table P2](https://data.census.gov/table/DECENNIALPL2020.P2?g=040XX00US36) contains population totals broken down by both race _and_ Hispanic/Latino origin. Let's retrieve county-level statistics from this table. (As with Table P1, column definitions are available in the [API documentation](https://api.census.gov/data/2020/dec/pl/variables.html).) When we rename columns derived from Table P2, **we'll use the prefix `nh_` for columns containing non-Hispanic population and the prefix `h_` for columns containing Hispanic population.**

# %%
p2_non_hispanic_population_columns = {
    "P2_005N": "nh_white",        # White alone
    "P2_006N": "nh_black",        # Black or African American alone
    "P2_007N": "nh_amin",         # American Indian and Alaska Native alone
    "P2_008N": "nh_asian",        # Asian alone
    "P2_009N": "nh_nhpi",         # Native Hawaiian and Other Pacific Islander alone
    "P2_010N": "nh_other",        # Some Other Race alone
    "P2_011N": "nh_two_or_more",  # Two or more races
}

# %%
county_non_hispanic_populations = census.pl.get(
    ("NAME", *p2_non_hispanic_population_columns),
    geo={
        "for": "county:*",
        "in": f"state:{state.fips}",
    }
)

# %%
race_ethnicity_df = pd.DataFrame(county_non_hispanic_populations)

# %%
race_ethnicity_df.head(5)
# Out:
#                            NAME   P2_005N   P2_006N  P2_007N  P2_008N  \
# 0       Albany County, New York  210895.0   40667.0    494.0  24363.0
# 1     Allegany County, New York   42327.0     809.0     91.0    373.0
# 2        Bronx County, New York  130796.0  419393.0   3087.0  67766.0
# 3       Broome County, New York  156173.0   11547.0    413.0   9337.0
# 4  Cattaraugus County, New York   67554.0     996.0   2661.0    560.0
#
#    P2_009N  P2_010N  P2_011N state county
# 0    166.0   1821.0  14847.0    36    001
# 1      6.0    218.0   1667.0    36    003
# 2    457.0  16322.0  28370.0    36    005
# 3     64.0    864.0  10000.0    36    007
# 4      9.0    212.0   3435.0    36    009

# %% [markdown]
# We can apply the same postprocessing steps we applied to Table P1 to clean up the column names.

# %%
race_ethnicity_df = race_ethnicity_df.rename(
    columns={"NAME": "name", **p2_non_hispanic_population_columns}
).drop(
    columns=["state", "county"]
).set_index("name")

# %%
race_ethnicity_df
# Out:
#                               nh_white  nh_black  nh_amin  nh_asian  nh_nhpi  \
# name
# Albany County, New York       210895.0   40667.0    494.0   24363.0    166.0
# Allegany County, New York      42327.0     809.0     91.0     373.0      6.0
# Bronx County, New York        130796.0  419393.0   3087.0   67766.0    457.0
# Broome County, New York       156173.0   11547.0    413.0    9337.0     64.0
# Cattaraugus County, New York   67554.0     996.0   2661.0     560.0      9.0
# ...                                ...       ...      ...       ...      ...
# Washington County, New York    54605.0    1563.0    149.0     319.0     22.0
# Wayne County, New York         79230.0    2397.0    171.0     473.0     13.0
# Westchester County, New York  497684.0  131010.0   1017.0   64907.0    150.0
# Wyoming County, New York       35579.0    1852.0     83.0     217.0      6.0
# Yates County, New York         23049.0     145.0     28.0      93.0      8.0
#
#                               nh_other  nh_two_or_more
# name
# Albany County, New York         1821.0         14847.0
# Allegany County, New York        218.0          1667.0
# Bronx County, New York         16322.0         28370.0
# Broome County, New York          864.0         10000.0
# Cattaraugus County, New York     212.0          3435.0
# ...                                ...             ...
# Washington County, New York      143.0          2740.0
# Wayne County, New York           272.0          4213.0
# Westchester County, New York    8651.0         31704.0
# Wyoming County, New York          77.0          1227.0
# Yates County, New York            77.0           700.0
#
# [62 rows x 7 columns]

# %% [markdown]
# Table P2 only includes _non_-Hispanic population by race, but we can easily derive Hispanic population by race by incorporating totals from Table P1.

# %%
for category in categories:
    race_ethnicity_df[f"h_{category}"] = race_df[category] - race_ethnicity_df[f"nh_{category}"]

# %%
race_ethnicity_df.head(5)
# Out:
#                               nh_white  nh_black  nh_amin  nh_asian  nh_nhpi  \
# name
# Albany County, New York       210895.0   40667.0    494.0   24363.0    166.0
# Allegany County, New York      42327.0     809.0     91.0     373.0      6.0
# Bronx County, New York        130796.0  419393.0   3087.0   67766.0    457.0
# Broome County, New York       156173.0   11547.0    413.0    9337.0     64.0
# Cattaraugus County, New York   67554.0     996.0   2661.0     560.0      9.0
#
#                               nh_other  nh_two_or_more  h_white  h_black  \
# name
# Albany County, New York         1821.0         14847.0   4601.0   2539.0
# Allegany County, New York        218.0          1667.0    228.0     20.0
# Bronx County, New York         16322.0         28370.0  76777.0  67725.0
# Broome County, New York          864.0         10000.0   2501.0   1137.0
# Cattaraugus County, New York     212.0          3435.0    574.0     47.0
#
#                                h_amin  h_asian  h_nhpi   h_other  \
# name
# Albany County, New York         351.0    110.0    17.0    7052.0
# Allegany County, New York         0.0      6.0     3.0     460.0
# Bronx County, New York        18452.0   1793.0  1183.0  476730.0
# Broome County, New York         143.0     35.0    20.0    3111.0
# Cattaraugus County, New York     45.0      7.0     5.0     359.0
#
#                               h_two_or_more
# name
# Albany County, New York              6925.0
# Allegany County, New York             248.0
# Bronx County, New York             163803.0
# Broome County, New York              3338.0
# Cattaraugus County, New York          578.0

# %%
race_ethnicity_df["total"] = race_ethnicity_df.sum(axis=1)

# %%
non_hispanic_categories = list(p2_non_hispanic_population_columns.values())
non_hispanic_categories
# Out:
# ['nh_white',
#  'nh_black',
#  'nh_amin',
#  'nh_asian',
#  'nh_nhpi',
#  'nh_other',
#  'nh_two_or_more']

# %% [markdown]
# For convenience, let's construct subtotals for the Hispanic and non-Hispanic populations.

# %%
race_ethnicity_df["nh_total"] = race_ethnicity_df[non_hispanic_categories].sum(axis=1)

# %%
hispanic_categories = [cat.replace("nh_", "h_") for cat in non_hispanic_categories]
hispanic_categories
# Out:
# ['h_white',
#  'h_black',
#  'h_amin',
#  'h_asian',
#  'h_nhpi',
#  'h_other',
#  'h_two_or_more']

# %%
race_ethnicity_df["h_total"] = race_ethnicity_df[hispanic_categories].sum(axis=1)

# %%
race_ethnicity_df.head(5)
# Out:
#                               nh_white  nh_black  nh_amin  nh_asian  nh_nhpi  \
# name
# Albany County, New York       210895.0   40667.0    494.0   24363.0    166.0
# Allegany County, New York      42327.0     809.0     91.0     373.0      6.0
# Bronx County, New York        130796.0  419393.0   3087.0   67766.0    457.0
# Broome County, New York       156173.0   11547.0    413.0    9337.0     64.0
# Cattaraugus County, New York   67554.0     996.0   2661.0     560.0      9.0
#
#                               nh_other  nh_two_or_more  h_white  h_black  \
# name
# Albany County, New York         1821.0         14847.0   4601.0   2539.0
# Allegany County, New York        218.0          1667.0    228.0     20.0
# Bronx County, New York         16322.0         28370.0  76777.0  67725.0
# Broome County, New York          864.0         10000.0   2501.0   1137.0
# Cattaraugus County, New York     212.0          3435.0    574.0     47.0
#
#                                h_amin  h_asian  h_nhpi   h_other  \
# name
# Albany County, New York         351.0    110.0    17.0    7052.0
# Allegany County, New York         0.0      6.0     3.0     460.0
# Bronx County, New York        18452.0   1793.0  1183.0  476730.0
# Broome County, New York         143.0     35.0    20.0    3111.0
# Cattaraugus County, New York     45.0      7.0     5.0     359.0
#
#                               h_two_or_more      total  nh_total   h_total
# name
# Albany County, New York              6925.0   314848.0  293253.0   21595.0
# Allegany County, New York             248.0    46456.0   45491.0     965.0
# Bronx County, New York             163803.0  1472654.0  666191.0  806463.0
# Broome County, New York              3338.0   198683.0  188398.0   10285.0
# Cattaraugus County, New York          578.0    77042.0   75427.0    1615.0

# %% [markdown]
# It's always important to double-check our calculations. Here, we verify that the Hispanic and non-Hispanic totals add up to the overall population total in each county.
#
# **Note: an [assert](https://docs.python.org/3/reference/simple_stmts.html) statement in Python is useful when de-bugging!** In this case, if the sum of your Hispanic and non-Hispanic populations does not add up to the total population, the assert will throw an error and you will not be able to run the code in this cell. This kind of behavior can be preferable if you want to ensure that certain conditions in your data are true and raise a noticeable error if they are not.

# %%
assert (race_ethnicity_df["h_total"] + race_ethnicity_df["nh_total"] == race_ethnicity_df["total"]).all()

# %% [markdown]
# Now that we've broken down the state population along two dimensions (race and Hispanic/Latino origin), we can answer some more sophisticated demographic questions: for instance, how does the distribution of racial identification differ between the Hispanic and non-Hispanic populations?

# %%
ax = race_ethnicity_df[["nh_total", "h_total"]].rename(
    columns={"nh_total": "non-Hispanic", "h_total": "Hispanic"}
).sum(axis=0).plot.pie(figsize=(6, 6), autopct="%1.1f%%")
ax.set_ylabel("")
ax.set_title(f"Population of {state} (state) by Hispanic/Latino origin")
plt.show()

# %%
ax = race_ethnicity_df[hispanic_categories].rename(columns={
    "h_other": "SomeOther",
    "h_asian": "Asian",
    "h_black": "Black",
    "h_white": "White",
    "h_two_or_more": "Multi",
    "h_amin": "AMIN",
    "h_nhpi": "NHPI",
}).sum(axis=0).sort_values(ascending=False).plot.bar(figsize=(6, 6), rot=0)
ax.set_title(f"Hispanic population of {state}")
plt.show()

# %%
ax = race_ethnicity_df[non_hispanic_categories].rename(columns={
    "nh_other": "SomeOther",
    "nh_asian": "Asian",
    "nh_black": "Black",
    "nh_white": "White",
    "nh_two_or_more": "Multi",
    "nh_amin": "AMIN",
    "nh_nhpi": "NHPI",
}).sum(axis=0).sort_values(ascending=False).plot.bar(figsize=(6, 6), rot=0)
ax.set_title(f"non-Hispanic population of {state}")
plt.show()

# %% [markdown]
# ## Homework 2, due Tuesday Feb 11, 1:25pm

# %% [markdown]
# For the **data product** part of your homework, explore the census race/ethnicity data.  Pose ONE question and show us a plot that answers it.  Here are some examples to get you thinking...
# - How does the share of "white" people change in Texas if I only sort by race (ignoring ethnicity), or if I consider both race and ethnicity and treat Hispanic as a race?  (This could be a pair of pie charts side-by-side, for instance.)
# - Which state had its number of multi-racial respondents jump most in absolute numbers between the 2010 and 2020 Census?
# - What's the share of Hispanic respondents choosing "Some Other Race" in California? Is it very different from Florida?
# - What's the Whitest state with at least 3 million people?
# - Which state has the highest share of people who said they belong to ALL SIX races?  (note: to do this, you'd need to fetch new columns from the API)
#
# Be creative!

# %% [markdown]
# For the **reading response** part of your homework, refer to the chapter by Nobles.  Pick out and quote one juicy sentence that you underlined when you read the chapter.  React to it and connect it to something from either Scott or Hacking (two other authors we've been discussing).

# %% [markdown]
# ## My personal practice for mondays presentation

# %%
#get all united states counties into one single table
uscounty_populations = census.pl.get(
    ("NAME", *p1_population_columns),
    geo={
        "for": "county:*",
        "in": f"state:*",
    }
)

#Make into a dataframe 
usrace_df = pd.DataFrame(uscounty_populations)
#renmae columns 
usrace_df = usrace_df.rename(
    columns={"NAME": "name", **p1_population_columns}
).drop(
    columns=["state", "county"]
).set_index("name")
usrace_df.head(3)
# Out:
#                             white    black    amin   asian   nhpi   other  \
# name
# Autauga County, Alabama   42160.0  11445.0   217.0   881.0   35.0   910.0
# Baldwin County, Alabama  189399.0  18217.0  1582.0  2067.0  143.0  5335.0
# Barbour County, Alabama   11317.0  11933.0   116.0   117.0    1.0  1039.0
#
#                          two_or_more
# name
# Autauga County, Alabama       3157.0
# Baldwin County, Alabama      15024.0
# Barbour County, Alabama        700.0

# %%
#saves it to a list of decoded titles 
usp2_non_hispanic_population_columns = {
    "P2_005N": "nh_white",        # White alone
    "P2_006N": "nh_black",        # Black or African American alone
    "P2_007N": "nh_amin",         # American Indian and Alaska Native alone
    "P2_008N": "nh_asian",        # Asian alone
    "P2_009N": "nh_nhpi",         # Native Hawaiian and Other Pacific Islander alone
    "P2_010N": "nh_other",        # Some Other Race alone
    "P2_011N": "nh_two_or_more",  # Two or more races
}


#add hispanic 
uscounty_non_hispanic_populations = census.pl.get(
    ("NAME", *p2_non_hispanic_population_columns),
    geo={
        "for": "county:*",
        "in": f"state:*",
    }
)


#saves it to a dataframe
usrace_ethnicity_df = pd.DataFrame(uscounty_non_hispanic_populations)
#renaming the colums 
usrace_ethnicity_df = usrace_ethnicity_df.rename(
    columns={"NAME": "name", **p2_non_hispanic_population_columns}
).drop(
    columns=["state", "county"]
).set_index("name")

usrace_ethnicity_df
# Out:
#                              nh_white  nh_black  nh_amin  nh_asian  nh_nhpi  \
# name
# Autauga County, Alabama       41582.0   11352.0    184.0     873.0     22.0
# Baldwin County, Alabama      186495.0   18001.0   1291.0    2029.0    122.0
# Barbour County, Alabama       11086.0   11850.0     58.0     103.0      0.0
# Bibb County, Alabama          16442.0    4390.0     39.0      26.0      9.0
# Blount County, Alabama        49764.0     826.0    188.0     174.0     11.0
# ...                               ...       ...      ...       ...      ...
# Renville County, Minnesota    12766.0      60.0    103.0      61.0      5.0
# Roseau County, Minnesota      13700.0      85.0    229.0     398.0     10.0
# Sherburne County, Minnesota   84761.0    3648.0    390.0    1277.0     22.0
# Steele County, Minnesota      31376.0    1359.0     65.0     330.0     18.0
# Todd County, Minnesota        22117.0      95.0     76.0      97.0     72.0
#
#                              nh_other  nh_two_or_more
# name
# Autauga County, Alabama         185.0          2490.0
# Baldwin County, Alabama         775.0         10368.0
# Barbour County, Alabama          63.0           553.0
# Bibb County, Alabama             47.0           600.0
# Blount County, Alabama          100.0          2300.0
# ...                               ...             ...
# Renville County, Minnesota       27.0           382.0
# Roseau County, Minnesota         56.0           615.0
# Sherburne County, Minnesota     313.0          3952.0
# Steele County, Minnesota         58.0          1060.0
# Todd County, Minnesota           65.0           532.0
#
# [3221 rows x 7 columns]

# %%
#create a column called state
usrace_ethnicity_df["state_name"]=usrace_ethnicity_df.index.str.split(",").str[1]



#this adds the hispanic catagorty for all races 
for category in categories:
    usrace_ethnicity_df[f"h_{category}"] = usrace_df[category] - usrace_ethnicity_df[f"nh_{category}"]

#adds total for the non hispanics so at this point we should have hispanic totals and non hispanc totals 
usrace_ethnicity_df["nh_total"] = usrace_ethnicity_df[non_hispanic_categories].sum(axis=1)


#hispanic totals 
usrace_ethnicity_df["h_total"] = usrace_ethnicity_df[hispanic_categories].sum(axis=1)

usrace_ethnicity_df
# Out:
#                              nh_white  nh_black  nh_amin  nh_asian  nh_nhpi  \
# name
# Autauga County, Alabama       41582.0   11352.0    184.0     873.0     22.0
# Baldwin County, Alabama      186495.0   18001.0   1291.0    2029.0    122.0
# Barbour County, Alabama       11086.0   11850.0     58.0     103.0      0.0
# Bibb County, Alabama          16442.0    4390.0     39.0      26.0      9.0
# Blount County, Alabama        49764.0     826.0    188.0     174.0     11.0
# ...                               ...       ...      ...       ...      ...
# Renville County, Minnesota    12766.0      60.0    103.0      61.0      5.0
# Roseau County, Minnesota      13700.0      85.0    229.0     398.0     10.0
# Sherburne County, Minnesota   84761.0    3648.0    390.0    1277.0     22.0
# Steele County, Minnesota      31376.0    1359.0     65.0     330.0     18.0
# Todd County, Minnesota        22117.0      95.0     76.0      97.0     72.0
#
#                              nh_other  nh_two_or_more  state_name  h_white  \
# name
# Autauga County, Alabama         185.0          2490.0     Alabama    578.0
# Baldwin County, Alabama         775.0         10368.0     Alabama   2904.0
# Barbour County, Alabama          63.0           553.0     Alabama    231.0
# Bibb County, Alabama             47.0           600.0     Alabama    113.0
# Blount County, Alabama          100.0          2300.0     Alabama    899.0
# ...                               ...             ...         ...      ...
# Renville County, Minnesota       27.0           382.0   Minnesota    392.0
# Roseau County, Minnesota         56.0           615.0   Minnesota     62.0
# Sherburne County, Minnesota     313.0          3952.0   Minnesota    743.0
# Steele County, Minnesota         58.0          1060.0   Minnesota    775.0
# Todd County, Minnesota           65.0           532.0   Minnesota    298.0
#
#                              h_black  h_amin  h_asian  h_nhpi  h_other  \
# name
# Autauga County, Alabama         93.0    33.0      8.0    13.0    725.0
# Baldwin County, Alabama        216.0   291.0     38.0    21.0   4560.0
# Barbour County, Alabama         83.0    58.0     14.0     1.0    976.0
# Bibb County, Alabama            23.0    21.0      6.0     0.0    418.0
# Blount County, Alabama          19.0   149.0      4.0    13.0   3331.0
# ...                              ...     ...      ...     ...      ...
# Renville County, Minnesota       9.0    23.0      8.0     2.0    469.0
# Roseau County, Minnesota         2.0    12.0      0.0     0.0     72.0
# Sherburne County, Minnesota     18.0    54.0     18.0     0.0    876.0
# Steele County, Minnesota        14.0    55.0     12.0     4.0   1355.0
# Todd County, Minnesota          24.0    23.0      4.0     0.0   1238.0
#
#                              h_two_or_more  nh_total  h_total
# name
# Autauga County, Alabama              667.0   56688.0   2117.0
# Baldwin County, Alabama             4656.0  219081.0  12686.0
# Barbour County, Alabama              147.0   23713.0   1510.0
# Bibb County, Alabama                 159.0   21553.0    740.0
# Blount County, Alabama              1356.0   53363.0   5771.0
# ...                                    ...       ...      ...
# Renville County, Minnesota           416.0   13404.0   1319.0
# Roseau County, Minnesota              90.0   15093.0    238.0
# Sherburne County, Minnesota         1111.0   94363.0   2820.0
# Steele County, Minnesota             925.0   34266.0   3140.0
# Todd County, Minnesota               621.0   23054.0   2208.0
#
# [3221 rows x 17 columns]

# %%
group_state= usrace_ethnicity_df.groupby ("state_name")

#gets columns 
usrace_ethnicity_df.columns

SOR_states= usrace_ethnicity_df[["nh_other", "state_name", "h_other"]].groupby("state_name")


state_level_df = usrace_ethnicity_df.groupby("state_name").sum(numeric_only=True).reset_index()

state_level_df.head(3)


#totaling the hispanic and non hispanic totals
state_level_df["other_totals"]= state_level_df["h_other"]+state_level_df["nh_other"]

state_level_df["total"]= state_level_df["h_total"]+ state_level_df["nh_total"]

categories1= [ 'nh_white', 'nh_black', 'nh_amin', 'nh_asian', 'nh_nhpi',
       'nh_other', 'nh_two_or_more', 'h_white', 'h_black', 'h_amin', 'h_asian',
       'h_nhpi', 'h_other', 'h_two_or_more']
for col in categories1:
    state_level_df[f"{col}_pct"] = 100 * state_level_df[col] / state_level_df["total"]

state_level_df.head(3)
# Out:
#   state_name   nh_white   nh_black   nh_amin  nh_asian  nh_nhpi  nh_other  \
# 0    Alabama  3171351.0  1288159.0   23119.0   75918.0   2612.0   14455.0
# 1     Alaska   421758.0    20731.0  108838.0   43449.0  12455.0    4575.0
# 2    Arizona  3816547.0   317161.0  263930.0  248837.0  14323.0   31611.0
#
#    nh_two_or_more   h_white  h_black  ...  nh_nhpi_pct  nh_other_pct  \
# 0        184618.0   49101.0   8003.0  ...     0.051988      0.287703
# 1         71761.0   13634.0   1167.0  ...     1.698276      0.623815
# 2        266840.0  505790.0  21989.0  ...     0.200280      0.442019
#
#    nh_two_or_more_pct  h_white_pct  h_black_pct  h_amin_pct  h_asian_pct  \
# 0            3.674517     0.977275     0.159287    0.209105     0.014768
# 1            9.784821     1.859036     0.159124    0.373198     0.079494
# 2            3.731244     7.072500     0.307474    0.777207     0.120157
#
#    h_nhpi_pct  h_other_pct  h_two_or_more_pct
# 0    0.007404     2.447874           1.439709
# 1    0.033134     1.867626           2.422037
# 2    0.029001    12.140932          10.207170
#
# [3 rows x 33 columns]

# %%
#state_level_df.set_index("state_name", inplace=True)

# Choose a specific row by state name
row = state_level_df[state_level_df["state_name"] == "Alabama"].iloc[0]

labels = ['nh_other', 'h_other']
values = [row['nh_other'], row['h_other']]

fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Left: Combined pie (Col1 + Col2)
axes[0].pie([sum(values)], labels=['nh_other + h_other'], autopct='%1.1f%%')
axes[0].set_title(f"Combined for {row['state_name']}")

# Right: Individual pie (Col1 vs Col2)
axes[1].pie(values, labels=labels, autopct='%1.1f%%')
axes[1].set_title(f"Col1 vs Col2 for {row['state_name']}")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\homsb\notebooks\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'state_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 4
#       1 #state_level_df.set_index("state_name", inplace=True)
#       2
#       3 # Choose a specific row by state name
# ----> 4 row = state_level_df[state_level_df["state_name"] == "Alabama"].iloc[0]
#       6 labels = ['nh_other', 'h_other']
#       7 values = [row['nh_other'], row['h_other']]
#
# File c:\Users\homsb\notebooks\.venv\Lib\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File c:\Users\homsb\notebooks\.venv\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'state_name'

# %%
# Choose a state, e.g., "California"
chosen_state = " Vermont"

# Ensure 'state_name' is a column (reset index if needed)
if "state_name" not in state_level_df.columns:
	state_level_df = state_level_df.reset_index()

# Get the row for the chosen state
filtered = state_level_df[state_level_df["state_name"] == chosen_state]
if filtered.empty:
	print(f"State '{chosen_state}' not found in the data. Available states are:\n{state_level_df['state_name'].unique()}")
else:
	row = filtered.iloc[0]
	labels = ['Non-Hispanic Other', 'Hispanic Other']
	values = [row['nh_other'], row['h_other']]

	plt.figure(figsize=(6, 6))
	plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=90)
	plt.title(f'"Other" Race by Ethnicity in {chosen_state}')
	plt.show()

# %%
# Choose a state, e.g., "Vermont"
chosen_state = "California"

# Strip whitespace from state_name column and chosen_state
state_level_df["state_name"] = state_level_df["state_name"].str.strip()
chosen_state = chosen_state.strip()



    # Combine Hispanic and Non-Hispanic for each race
combined_labels = [
        "White", "Black", "American Indian/Alaska Native", "Asian",
        "Native Hawaiian/Pacific Islander", "Other", "Two or More"
    ]
combined_values = [
        row["nh_white"] + row["h_white"],
        row["nh_black"] + row["h_black"],
        row["nh_amin"] + row["h_amin"],
        row["nh_asian"] + row["h_asian"],
        row["nh_nhpi"] + row["h_nhpi"],
        row["nh_other"] + row["h_other"],
        row["nh_two_or_more"] + row["h_two_or_more"],
    ]

plt.show()
    # Pie chart with all races combined (no hispanic/non-hispanic split)
plt.figure(figsize=(10, 10))
plt.pie(combined_values, labels=combined_labels, autopct='%1.1f%%', startangle=90)
plt.title(f'Population by Race in {chosen_state} (Hispanic and Non-Hispanic Combined)')
plt.show()
 #a state, e.g., "Vermont"

# %%
# separating out hispanic and non hispanic other
chosen_state = "California"

# Strip whitespace from state_name column and chosen_state
state_level_df["state_name"] = state_level_df["state_name"].str.strip()
chosen_state = chosen_state.strip()



    # Combine Hispanic and Non-Hispanic for each race
combined_labels = [
        "White", "Black", "American Indian/Alaska Native", "Asian",
        "Native Hawaiian/Pacific Islander", "Other", "Two or More"
    ]
combined_values = [
        row["nh_white"] + row["h_white"],
        row["nh_black"] + row["h_black"],
        row["nh_amin"] + row["h_amin"],
        row["nh_asian"] + row["h_asian"],
        row["nh_nhpi"] + row["h_nhpi"],
        row["nh_other"] + row["h_other"],
        row["nh_two_or_more"] + row["h_two_or_more"],
    ]

plt.show()
    # Pie chart with all races combined (no hispanic/non-hispanic split)
plt.figure(figsize=(10, 10))
plt.pie(combined_values, labels=combined_labels, autopct='%1.1f%%', startangle=90)
plt.title(f'Population by Race in {chosen_state} (Hispanic and Non-Hispanic Combined)')
plt.show()

# %%
chosen_state = "Vermont"
row = state_level_df[state_level_df["state_name"] == chosen_state].iloc[0]

labels = [
    "White", "Black", "American Indian/Alaska Native", "Asian",
    "Native Hawaiian/Pacific Islander", "Non-Hispanic Other", "Hispanic Other", "Two or More"
]
values = [
    row["nh_white"] + row["h_white"],
    row["nh_black"] + row["h_black"],
    row["nh_amin"] + row["h_amin"],
    row["nh_asian"] + row["h_asian"],
    row["nh_nhpi"] + row["h_nhpi"],
    row["nh_other"],
    row["h_other"],
    row["nh_two_or_more"] + row["h_two_or_more"],
]

plt.figure(figsize=(10, 10))
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title(f'Population by Race in {chosen_state} (Other split by Ethnicity)')
plt.show()

# %%
chosen_state = "Vermont"
row = state_level_df[state_level_df["state_name"] == chosen_state].iloc[0]

labels = [
 "Black", "American Indian/Alaska Native", "Asian",
    "Native Hawaiian/Pacific Islander", "Non-Hispanic Other", "Hispanic Other", "Two or More"
]
values = [
    row["nh_black"] + row["h_black"],
    row["nh_amin"] + row["h_amin"],
    row["nh_asian"] + row["h_asian"],
    row["nh_nhpi"] + row["h_nhpi"],
    row["nh_other"],
    row["h_other"],
    row["nh_two_or_more"] + row["h_two_or_more"],
]

plt.figure(figsize=(10, 10))
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=90 , rotatelabels=45)
plt.title(f'Population by Race in {chosen_state} (Other split by Ethnicity) without white people')
plt.show()

# %% [markdown]
# Making the Scatterplot

# %%
state_level_df['sor_total_pct'] = state_level_df['nh_other_pct'] + state_level_df['h_other_pct']

y= state_level_df["sor_total_pct"]
x=state_level_df["state_name"]
fig, ax = plt.subplots(figsize=(20, 20))
ax.histogram(x,y)
ax.set_xticks(x,state_level_df['state_name'], rotation=90)
ax.set_xlabel('States')
ax.set_ylabel('Percentage of SOR')
#plt.ylabel("percent")
plt.title("percent of some other race (SOR) per state ")
plt.show()
